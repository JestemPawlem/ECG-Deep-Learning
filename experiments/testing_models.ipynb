# %%
import sys
from pathlib import Path

BASE_DIR = Path().resolve().parent
sys.path.append(str(BASE_DIR))

# %%
from training.run_experiment import run_experiment

from models.cnn import CNN
from models.cnn_fkan import CNN_FKAN
from models.cnn_lstm import CNN_LSTM
from models.cnn_lstm_fkan import CNN_LSTM_FKAN
from models.cnn_gru import CNN_GRU
from models.cnn_gru_fkan import CNN_GRU_FKAN
from models.gru import GRU
from models.resnet import ResNet

# %%
run_experiment(
    model_class=CNN,
    model_name='CNN',
    epochs=100,
    lr=0.001,
    model_kwargs={
        'num_classes': 4,
        'input_channels': 12,
        'conv_dropout': 0.3,
        'conv_channels': [32, 64, 128],
        'fc_dropout': 0.5,
        'fc_features': [128]
    }
);
# Out:
# Running experiment CNN on: cuda
# Model parameters: 91,620
# Epoch 01/100:
# 	Train Loss: 0.6769 | ROC AUC: 72.26% | PR AUC: 40.15%
# 	Val Loss:   0.5678 | ROC AUC: 82.99% | PR AUC: 56.39%
# Epoch 02/100:
# 	Train Loss: 0.5793 | ROC AUC: 81.40% | PR AUC: 51.71%
# 	Val Loss:   0.5344 | ROC AUC: 84.32% | PR AUC: 60.85%
# Epoch 03/100:
# 	Train Loss: 0.5537 | ROC AUC: 82.88% | PR AUC: 56.38%
# 	Val Loss:   0.5244 | ROC AUC: 84.58% | PR AUC: 62.04%
# Epoch 04/100:
# 	Train Loss: 0.5402 | ROC AUC: 83.61% | PR AUC: 58.79%
# 	Val Loss:   0.5150 | ROC AUC: 85.33% | PR AUC: 64.68%
# Epoch 05/100:
# 	Train Loss: 0.5246 | ROC AUC: 84.54% | PR AUC: 61.80%
# 	Val Loss:   0.4972 | ROC AUC: 85.69% | PR AUC: 66.18%
# Epoch 06/100:
# 	Train Loss: 0.5148 | ROC AUC: 85.10% | PR AUC: 63.30%
# 	Val Loss:   0.4928 | ROC AUC: 86.03% | PR AUC: 66.64%
# Epoch 07/100:
# 	Train Loss: 0.5066 | ROC AUC: 85.62% | PR AUC: 64.53%
# 	Val Loss:   0.4870 | ROC AUC: 86.28% | PR AUC: 67.52%
# Epoch 08/100:
# ...

# %%
run_experiment(
    model_class=CNN_FKAN,
    model_name='CNN FKAN',
    epochs=100,
    batch_size=128,
    lr=0.001,
    model_kwargs={
        'num_classes': 4,
        'input_channels': 12,
        'conv_dropout': 0.3,
        'conv_channels': [32, 64, 128],
        'fkan_degree': 8,
        'fkan_features': [8]
    }
);
# Out:
# Running experiment CNN FKAN on: cuda
# Model parameters: 92,572
# Epoch 01/100:
# 	Train Loss: 0.7177 | ROC AUC: 66.77% | PR AUC: 35.46%
# 	Val Loss:   0.6363 | ROC AUC: 81.04% | PR AUC: 54.16%
# Epoch 02/100:
# 	Train Loss: 0.5795 | ROC AUC: 81.01% | PR AUC: 52.84%
# 	Val Loss:   0.5414 | ROC AUC: 84.21% | PR AUC: 60.61%
# Epoch 03/100:
# 	Train Loss: 0.5418 | ROC AUC: 83.53% | PR AUC: 59.40%
# 	Val Loss:   0.5124 | ROC AUC: 85.39% | PR AUC: 65.35%
# Epoch 04/100:
# 	Train Loss: 0.5161 | ROC AUC: 85.09% | PR AUC: 63.09%
# 	Val Loss:   0.4917 | ROC AUC: 86.50% | PR AUC: 68.04%
# Epoch 05/100:
# 	Train Loss: 0.4998 | ROC AUC: 86.10% | PR AUC: 65.30%
# 	Val Loss:   0.4858 | ROC AUC: 86.82% | PR AUC: 67.74%
# Epoch 06/100:
# 	Train Loss: 0.4900 | ROC AUC: 86.65% | PR AUC: 66.76%
# 	Val Loss:   0.5020 | ROC AUC: 86.71% | PR AUC: 68.22%
# Epoch 07/100:
# 	Train Loss: 0.4793 | ROC AUC: 87.24% | PR AUC: 68.26%
# 	Val Loss:   0.4672 | ROC AUC: 88.00% | PR AUC: 69.70%
# Epoch 08/100:
# ...

# %%
run_experiment(
    model_class=CNN_LSTM,
    model_name='CNN LSTM',
    epochs=100,
    batch_size=128,
    lr=0.001,
    model_kwargs={
        'num_classes': 4,
        'input_channels': 12,
        'conv_dropout': 0.3,
        'conv_channels': [32, 64, 128],
        'lstm_dropout': 0.0,
        'lstm_hidden': 64,
        'lstm_layers': 1,
        'lstm_bidirectional': True,
        'fc_dropout': 0.5,
        'fc_features': [128]
    }
);
# Out:
# Running experiment CNN LSTM on: cuda
# Model parameters: 212,196
# Epoch 01/100:
# 	Train Loss: 0.7271 | ROC AUC: 63.72% | PR AUC: 31.24%
# 	Val Loss:   0.6543 | ROC AUC: 75.89% | PR AUC: 43.08%
# Epoch 02/100:
# 	Train Loss: 0.6278 | ROC AUC: 76.76% | PR AUC: 44.90%
# 	Val Loss:   0.5641 | ROC AUC: 81.86% | PR AUC: 54.18%
# Epoch 03/100:
# 	Train Loss: 0.5766 | ROC AUC: 80.90% | PR AUC: 51.09%
# 	Val Loss:   0.5441 | ROC AUC: 83.34% | PR AUC: 57.45%
# Epoch 04/100:
# 	Train Loss: 0.5571 | ROC AUC: 82.37% | PR AUC: 54.88%
# 	Val Loss:   0.5225 | ROC AUC: 84.36% | PR AUC: 59.38%
# Epoch 05/100:
# 	Train Loss: 0.5416 | ROC AUC: 83.42% | PR AUC: 58.02%
# 	Val Loss:   0.5190 | ROC AUC: 84.85% | PR AUC: 61.88%
# Epoch 06/100:
# 	Train Loss: 0.5301 | ROC AUC: 84.11% | PR AUC: 60.39%
# 	Val Loss:   0.5051 | ROC AUC: 85.23% | PR AUC: 64.29%
# Epoch 07/100:
# 	Train Loss: 0.5223 | ROC AUC: 84.65% | PR AUC: 62.05%
# 	Val Loss:   0.4990 | ROC AUC: 85.80% | PR AUC: 65.25%
# Epoch 08/100:
# ...

# %%
run_experiment(
    model_class=CNN_LSTM_FKAN,
    model_name='CNN LSTM FKAN',
    epochs=100,
    batch_size=128,
    lr=0.001,
    model_kwargs={
        'num_classes': 4,
        'input_channels': 12,
        'conv_dropout': 0.3,
        'conv_channels': [32, 64, 128],
        'lstm_dropout': 0.0,
        'lstm_hidden': 64,
        'lstm_layers': 1,
        'lstm_bidirectional': True,
        'fkan_degree': 8,
        'fkan_features': [8]
    }
);
# Out:
# Running experiment CNN LSTM FKAN on: cuda
# Model parameters: 213,148
# Epoch 01/100:
# 	Train Loss: 0.7544 | ROC AUC: 57.28% | PR AUC: 25.80%
# 	Val Loss:   0.6774 | ROC AUC: 73.21% | PR AUC: 41.59%
# Epoch 02/100:
# 	Train Loss: 0.6312 | ROC AUC: 76.67% | PR AUC: 45.68%
# 	Val Loss:   0.5792 | ROC AUC: 82.46% | PR AUC: 56.99%
# Epoch 03/100:
# 	Train Loss: 0.5683 | ROC AUC: 81.71% | PR AUC: 54.85%
# 	Val Loss:   0.5546 | ROC AUC: 83.60% | PR AUC: 59.59%
# Epoch 04/100:
# 	Train Loss: 0.5448 | ROC AUC: 83.27% | PR AUC: 58.62%
# 	Val Loss:   0.5211 | ROC AUC: 84.47% | PR AUC: 62.50%
# Epoch 05/100:
# 	Train Loss: 0.5295 | ROC AUC: 84.14% | PR AUC: 61.19%
# 	Val Loss:   0.5236 | ROC AUC: 84.50% | PR AUC: 63.60%
# Epoch 06/100:
# 	Train Loss: 0.5188 | ROC AUC: 84.65% | PR AUC: 63.05%
# 	Val Loss:   0.5145 | ROC AUC: 84.84% | PR AUC: 64.01%
# Epoch 07/100:
# 	Train Loss: 0.5078 | ROC AUC: 85.33% | PR AUC: 64.30%
# 	Val Loss:   0.5054 | ROC AUC: 85.55% | PR AUC: 65.56%
# Epoch 08/100:
# ...

# %%
run_experiment(
    model_class=CNN_GRU,
    model_name='CNN GRU',
    epochs=100,
    batch_size=128,
    lr=0.001,
    model_kwargs={
        'num_classes': 4,
        'input_channels': 12,
        'conv_dropout': 0.3,
        'conv_channels': [32, 64, 128],
        'gru_dropout': 0.0,
        'gru_hidden': 64,
        'gru_layers': 1,
        'gru_bidirectional': True,
        'fc_dropout': 0.5,
        'fc_features': [128]
    }
);
# Out:
# Running experiment CNN GRU on: cuda
# Model parameters: 187,364
# Epoch 01/100:
# 	Train Loss: 0.7293 | ROC AUC: 63.22% | PR AUC: 31.01%
# 	Val Loss:   0.6455 | ROC AUC: 76.09% | PR AUC: 42.51%
# Epoch 02/100:
# 	Train Loss: 0.6242 | ROC AUC: 77.26% | PR AUC: 45.18%
# 	Val Loss:   0.5560 | ROC AUC: 82.93% | PR AUC: 56.72%
# Epoch 03/100:
# 	Train Loss: 0.5689 | ROC AUC: 81.54% | PR AUC: 52.43%
# 	Val Loss:   0.5311 | ROC AUC: 84.17% | PR AUC: 59.23%
# Epoch 04/100:
# 	Train Loss: 0.5497 | ROC AUC: 82.96% | PR AUC: 56.41%
# 	Val Loss:   0.5167 | ROC AUC: 84.89% | PR AUC: 62.57%
# Epoch 05/100:
# 	Train Loss: 0.5331 | ROC AUC: 83.97% | PR AUC: 59.89%
# 	Val Loss:   0.5048 | ROC AUC: 85.59% | PR AUC: 64.55%
# Epoch 06/100:
# 	Train Loss: 0.5173 | ROC AUC: 84.92% | PR AUC: 62.50%
# 	Val Loss:   0.4990 | ROC AUC: 85.97% | PR AUC: 65.80%
# Epoch 07/100:
# 	Train Loss: 0.5062 | ROC AUC: 85.58% | PR AUC: 64.29%
# 	Val Loss:   0.4891 | ROC AUC: 86.38% | PR AUC: 66.91%
# Epoch 08/100:
# ...

# %%
run_experiment(
    model_class=CNN_GRU_FKAN,
    model_name='CNN GRU FKAN',
    epochs=100,
    batch_size=128,
    lr=0.001,
    model_kwargs={
        'num_classes': 4,
        'input_channels': 12,
        'conv_dropout': 0.3,
        'conv_channels': [32, 64, 128],
        'gru_dropout': 0.0,
        'gru_hidden': 64,
        'gru_layers': 1,
        'gru_bidirectional': True,
        'fkan_degree': 8,
        'fkan_features': [8]
    }
);
# Out:
# Running experiment CNN GRU FKAN on: cuda
# Model parameters: 188,316
# Epoch 01/100:
# 	Train Loss: 0.7784 | ROC AUC: 56.03% | PR AUC: 25.03%
# 	Val Loss:   0.6767 | ROC AUC: 71.95% | PR AUC: 40.30%
# Epoch 02/100:
# 	Train Loss: 0.6455 | ROC AUC: 74.72% | PR AUC: 43.90%
# 	Val Loss:   0.6084 | ROC AUC: 80.07% | PR AUC: 54.85%
# Epoch 03/100:
# 	Train Loss: 0.5736 | ROC AUC: 81.25% | PR AUC: 53.95%
# 	Val Loss:   0.5393 | ROC AUC: 83.92% | PR AUC: 59.79%
# Epoch 04/100:
# 	Train Loss: 0.5450 | ROC AUC: 83.21% | PR AUC: 58.21%
# 	Val Loss:   0.5420 | ROC AUC: 84.17% | PR AUC: 60.74%
# Epoch 05/100:
# 	Train Loss: 0.5295 | ROC AUC: 84.16% | PR AUC: 60.87%
# 	Val Loss:   0.5127 | ROC AUC: 85.04% | PR AUC: 63.84%
# Epoch 06/100:
# 	Train Loss: 0.5161 | ROC AUC: 84.96% | PR AUC: 62.90%
# 	Val Loss:   0.5161 | ROC AUC: 85.30% | PR AUC: 64.13%
# Epoch 07/100:
# 	Train Loss: 0.5041 | ROC AUC: 85.62% | PR AUC: 64.34%
# 	Val Loss:   0.4891 | ROC AUC: 86.30% | PR AUC: 67.35%
# Epoch 08/100:
# ...

# %%
run_experiment(
    model_class=GRU,
    model_name='GRU',
    epochs=100,
    batch_size=128,
    model_kwargs={
        'num_classes': 4,
        'input_channels': 12,
        'gru_dropout': 0.2,
        'gru_hidden': 128,
        'gru_layers': 1,
        'gru_bidirectional': True,
        'fc_dropout': 0.5,
        'fc_features': [64]
    }
);
# Out:
# Running experiment GRU on: cuda
# Model parameters: 125,764
# Epoch 01/100:
# 	Train Loss: 0.7605 | ROC AUC: 53.71% | PR AUC: 22.98%
# 	Val Loss:   0.7165 | ROC AUC: 68.82% | PR AUC: 35.79%
# Epoch 02/100:
# 	Train Loss: 0.6914 | ROC AUC: 70.06% | PR AUC: 37.08%
# 	Val Loss:   0.6493 | ROC AUC: 74.40% | PR AUC: 43.37%
# Epoch 03/100:
# 	Train Loss: 0.6468 | ROC AUC: 74.87% | PR AUC: 42.44%
# 	Val Loss:   0.5930 | ROC AUC: 80.19% | PR AUC: 52.32%
# Epoch 04/100:
# 	Train Loss: 0.6155 | ROC AUC: 77.96% | PR AUC: 46.66%
# 	Val Loss:   0.5847 | ROC AUC: 80.30% | PR AUC: 51.20%
# Epoch 05/100:
# 	Train Loss: 0.6311 | ROC AUC: 76.06% | PR AUC: 45.29%
# 	Val Loss:   0.6464 | ROC AUC: 79.72% | PR AUC: 52.86%
# Epoch 06/100:
# 	Train Loss: 0.6035 | ROC AUC: 79.11% | PR AUC: 48.96%
# 	Val Loss:   0.5648 | ROC AUC: 82.22% | PR AUC: 54.70%
# Epoch 07/100:
# 	Train Loss: 0.5793 | ROC AUC: 81.02% | PR AUC: 52.24%
# 	Val Loss:   0.5499 | ROC AUC: 83.15% | PR AUC: 58.01%
# Epoch 08/100:
# ...

# %%
run_experiment(
    model_class=ResNet,
    model_name='ResNet',
    epochs=100,
    batch_size=128,
    lr=0.001,
    model_kwargs={
        'num_classes': 4,
        'input_channels': 12,
        'conv_dropout': 0.5,
        'conv_channels': [16, 16, 32, 32, 64, 64],
        'fc_dropout': 0.5,
        'fc_features': [64]
    }
);
# Out:
# Running experiment ResNet on: cuda
# Model parameters: 138,116
# Epoch 01/100:
# 	Train Loss: 0.6991 | ROC AUC: 68.64% | PR AUC: 37.62%
# 	Val Loss:   0.5827 | ROC AUC: 82.20% | PR AUC: 55.43%
# Epoch 02/100:
# 	Train Loss: 0.6022 | ROC AUC: 79.62% | PR AUC: 51.17%
# 	Val Loss:   0.5382 | ROC AUC: 84.34% | PR AUC: 60.65%
# Epoch 03/100:
# 	Train Loss: 0.5665 | ROC AUC: 82.03% | PR AUC: 55.74%
# 	Val Loss:   0.5154 | ROC AUC: 85.59% | PR AUC: 64.50%
# Epoch 04/100:
# 	Train Loss: 0.5424 | ROC AUC: 83.66% | PR AUC: 59.74%
# 	Val Loss:   0.4977 | ROC AUC: 86.06% | PR AUC: 66.21%
# Epoch 05/100:
# 	Train Loss: 0.5270 | ROC AUC: 84.57% | PR AUC: 61.91%
# 	Val Loss:   0.4957 | ROC AUC: 86.33% | PR AUC: 67.04%
# Epoch 06/100:
# 	Train Loss: 0.5152 | ROC AUC: 85.22% | PR AUC: 63.82%
# 	Val Loss:   0.4786 | ROC AUC: 86.91% | PR AUC: 68.22%
# Epoch 07/100:
# 	Train Loss: 0.5037 | ROC AUC: 85.96% | PR AUC: 65.05%
# 	Val Loss:   0.4727 | ROC AUC: 87.15% | PR AUC: 68.47%
# Epoch 08/100:
# ...
