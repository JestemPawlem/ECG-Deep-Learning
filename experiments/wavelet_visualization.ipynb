# %%
import sys
from pathlib import Path

BASE_DIR = Path().resolve().parent
sys.path.append(str(BASE_DIR))

# %%
from training.plot_wavelets import plot_wavelets

from models.wavkan import WavKAN

# %%
plot_wavelets(
    model_class=WavKAN,
    model_name='WavKAN',
    num_wavelets=25,  # Ile falek wyrysować (np. 9 na siatkę 3x3)
    channel_idx=0,  # Dla którego z 12 kanałów EKG pokazać wagi
)
