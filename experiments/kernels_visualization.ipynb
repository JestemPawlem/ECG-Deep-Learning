# %%
import sys
from pathlib import Path

BASE_DIR = Path().resolve().parent
sys.path.append(str(BASE_DIR))

# %%
from training.plot_kernels import plot_wavelet_kernels, plot_fourier_kernels

from models.wavkan import WavKAN
from models.fkan import FKAN

# %%
plot_wavelet_kernels(
    model_class=WavKAN,
    model_name='WavKAN',
    num_kernels=25,  # Ile falek wyrysować (np. 9 na siatkę 3x3)
    channel_idx=9,  # Dla którego z 12 kanałów EKG pokazać wagi
)

# %%
plot_fourier_kernels(model_class=FKAN,
                     model_name='FKAN',
                     num_kernels=25
                     channel_idx=9)
