# %%
import sys
from pathlib import Path

BASE_DIR = Path().resolve().parent
REPORTS_DIR = BASE_DIR / 'reports' / 'figures'
HISTORIES_DIR = BASE_DIR / 'reports' / 'histories'

sys.path.append(str(BASE_DIR))

# %%
from training.run_comparison import run_comparison

# %%
run_comparison(model_names=['CNN', 'CNN FKAN'],
               metric='f1')

# %%
run_comparison(model_names=['CNN LSTM', 'CNN LSTM FKAN'],
               metric='f1')

# %%
run_comparison(model_names=['CNN GRU', 'CNN GRU FKAN'],
               metric='f1')

# %%
model_names = [
    'CNN',
    'CNN LSTM',
    'CNN GRU',
    'GRU',
    'ResNet'
]

run_comparison(model_names=model_names,
               metric='f1')
